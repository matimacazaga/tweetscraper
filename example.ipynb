# %%
from tweetscraper import get_tweets
import datetime

# %%
tweets = get_tweets(usernames=['jimmieakesson', 'cfkargentina'], start_date=datetime.datetime(2014,6,1), end_date=datetime.datetime(2014,8,31), save=True)
# Out:
# [WDM] - Current google-chrome version is 85.0.4183
# [WDM] - Get LATEST driver version for 85.0.4183
# [WDM] - Driver [C:\Users\matim\.wdm\drivers\chromedriver\win32\85.0.4183.87\chromedriver.exe] found in cache
#
# Scraping tweets for jimmieakesson
# ----Found 51 tweets
#
# Scraping tweets for cfkargentina
# ----Found 344 tweets

# %%
tweets
# Out:
# {'jimmieakesson': [{'text': '@MartinG72\n Jo, hur det finansieras hade jag kunnat svara på. Däremot kan jag inte alla anslag utantill. Det förändrar dock inte saken.',
#    'date': datetime.datetime(2014, 8, 28, 0, 0),
#    'favs': 5,
#    'retweets': 1},
#   {'text': '"...valde de att inte ringa SD och dubbelkolla siffrorna med dem. De ringde i stället Socialdemokraterna..."',
#    'date': datetime.datetime(2014, 8, 28, 0, 0),
#    'favs': 34,
#    'retweets': 22},
#   {'text': 'Idag fick jag förmånen att skriva ett personligt, tills vidare hemligt, meddelande till självaste statsministern. Levereras imorgon :)',
#    'date': datetime.datetime(2014, 8, 28, 0, 0),
#    'favs': 58,
#    'retweets': 24},
#   {'text': 'Jimmie Åkesson frågades ut av P4 Östergötlands lyssnare',
#    'date': datetime.datetime(2014, 8, 28, 0, 0),
#    'favs': 7,
#    'retweets': 6},
#   {'text': 'Bra att regeringen nu lanserar vår kriminalpolitik. Då kan vi genomföra den redan nästa år :)',
# ...
